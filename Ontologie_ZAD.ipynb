# %% [markdown]
# <a href="https://colab.research.google.com/github/KasperczakMikolaj/UM-w-finansach/blob/main/Ontologie_ZAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdflib==4.2.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.2/344.2 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.5 MB/s eta 0:00:00
# ...

# %%
import rdflib

# %%
g = rdflib.Graph()

# %%
g.parse('http://dbpedia.org/resource/Berlin')
# Out:
# <Graph identifier=N5a265250aef64c98a92eb3f1a0678701 (<class 'rdflib.graph.Graph'>)>

# %%
for s,p,o in g:
  print("{} {} {}".format(s,p,o))
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
# http://dbpedia.org/resource/Krystyna_Skarbek http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Berlin
# http://dbpedia.org/resource/Brookfield_Property_Partners http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Berlin
# http://dbpedia.org/resource/82nd_Armored_Reconnaissance_Battalion http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Berlin
# http://dbpedia.org/resource/Kurt_Koffka_Medal http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Berlin
# http://dbpedia.org/resource/Charles-Étienne_Jordan http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Berlin
# http://dbpedia.org/resource/'SUP_Magazine http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Berlin
# http://dbpedia.org/resource/Berlin http://dbpedia.org/property/octMeanC 9.7
# ...
